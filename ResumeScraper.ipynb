# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# %%
url = "https://www.postjobfree.com/resumes?q=&n=&t=python+developer&d=&l=United+States&radius=25&r=100"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
title_tags = soup.find_all('h3', attrs={'class': 'itemTitle'})
links = ["https://www.postjobfree.com" + title_tag.a['href'] for title_tag in title_tags]
results = []
for link in links:
    res = requests.get(link)
    print(res.status_code, link)
    content = BeautifulSoup(res.content, 'html.parser')
    results.append({
        'job_title': content.find('div', attrs={'class': 'leftColumn'}).find('h1').get_text(),
        'resume': content.find('div', attrs={'class': 'normalText'}).get_text()[:-23]
    })
    time.sleep(3)
with open('resumes.csv', 'w') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=results[0].keys())
    writer.writeheader()
    for row in results:
        writer.writerow(row)
# Out:
# 200 https://www.postjobfree.com/resume/adlt8r/python-developer-cumming-ga
# 200 https://www.postjobfree.com/resume/adlltx/python-web-developer-binghamton-ny
# 200 https://www.postjobfree.com/resume/adllrc/python-software-ellicott-city-md
# 200 https://www.postjobfree.com/resume/adle1r/python-developer-columbus-oh
# 200 https://www.postjobfree.com/resume/adldv6/python-software-developer-chandler-az
# 200 https://www.postjobfree.com/resume/adk7el/web-developer-python-saint-paul-mn
# 200 https://www.postjobfree.com/resume/adk5om/software-developer-java-python-kearny-nj
# 200 https://www.postjobfree.com/resume/adk5mz/software-developer-python-texas-city-tx
# 200 https://www.postjobfree.com/resume/adk31u/developer-using-c-sharp-and-san-ramon-ca
# 200 https://www.postjobfree.com/resume/adk1lo/python-developer-seattle-wa
# 200 https://www.postjobfree.com/resume/adkxsk/python-developer-phoenix-az
# 200 https://www.postjobfree.com/resume/adkvd2/python-developer-columbus-oh
# 200 https://www.postjobfree.com/resume/adkvcp/python-developer-skokie-il
# 200 https://www.postjobfree.com/resume/adkraf/developer-python-charlotte-nc
# 200 https://www.postjobfree.com/resume/adkqqg/software-developer-java-c-alexandria-va
# 200 https://www.postjobfree.com/resume/adkoxe/python-software-developer-los-angeles-ca
# 200 https://www.postjobfree.com/resume/adkn31/developer-python-buffalo-ny
# 200 https://www.postjobfree.com/resume/adkieo/web-developer-python-charlotte-nc
# 200 https://www.postjobfree.com/resume/adkgns/python-developer-washington-dc
# 200 https://www.postjobfree.com/resume/adkfk6/python-developer-charlotte-nc
# 200 https://www.postjobfree.com/resume/adj0x1/python-developer-united-states
# 200 https://www.postjobfree.com/resume/adjzci/web-developer-python-chicago-il
# 200 https://www.postjobfree.com/resume/adjtm2/software-developer-python-irvine-ca
# 200 https://www.postjobfree.com/resume/adjr9s/python-software-developer-austin-tx
# 200 https://www.postjobfree.com/resume/adjq4z/web-developer-python-leander-tx
# 200 https://www.postjobfree.com/resume/adjq0i/python-developer-bensalem-township
# 200 https://www.postjobfree.com/resume/adjmdp/python-software-developer-richardson-tx
# 200 https://www.postjobfree.com/resume/adjl4f/python-software-developer-fairfax-va
# 200 https://www.postjobfree.com/resume/adjlzb/software-developer-python-cincinnati-oh
# 200 https://www.postjobfree.com/resume/adjltb/software-developer-python-apex-nc
# 200 https://www.postjobfree.com/resume/adjkry/python-developer-valley-stream-ny
# 200 https://www.postjobfree.com/resume/adjis4/web-developer-python-framingham-ma
# 200 https://www.postjobfree.com/resume/adjhu5/python-developer-ridgefield-park
# 200 https://www.postjobfree.com/resume/adjfnc/full-stack-python-developer-brooklyn-ny
# 200 https://www.postjobfree.com/resume/adjese/python-developer-paterson-nj
# 200 https://www.postjobfree.com/resume/adi5wv/developer-python-gainesville-fl
# 200 https://www.postjobfree.com/resume/adi2ei/python-developer-arlington-tx
# 200 https://www.postjobfree.com/resume/adivoj/python-developer-machine-nlp-dayton-oh
# 200 https://www.postjobfree.com/resume/adiu6y/python-software-delray-beach-fl
# 200 https://www.postjobfree.com/resume/adisyk/data-analyst-engineer-python-houston-tx
# 200 https://www.postjobfree.com/resume/adiq9j/software-developer-python-willimantic-ct
# 200 https://www.postjobfree.com/resume/adiov9/python-developer-tempe-az
# 200 https://www.postjobfree.com/resume/adin4z/software-developer-python-newark-nj
# 200 https://www.postjobfree.com/resume/adijzq/software-developer-python-united-states
# 200 https://www.postjobfree.com/resume/adihbw/python-developer-edison-nj
# 200 https://www.postjobfree.com/resume/adigar/developer-python-davis-ca
# 200 https://www.postjobfree.com/resume/adifuf/software-developer-python-irving-tx
# 200 https://www.postjobfree.com/resume/adifrv/software-developer-python-roosevelt-ny
# 200 https://www.postjobfree.com/resume/adie5y/software-developer-python-seattle-wa
# 200 https://www.postjobfree.com/resume/adh5o2/python-developer-leesburg-va
# 200 https://www.postjobfree.com/resume/adh0jr/python-sql-developer-r-sas-stamford-ct
# 200 https://www.postjobfree.com/resume/adhyfq/junior-python-developer-hillside-il
# 200 https://www.postjobfree.com/resume/adhyb5/developer-python-los-angeles-ca
# 200 https://www.postjobfree.com/resume/adhx85/python-developer-arlington-tx
# 200 https://www.postjobfree.com/resume/adhu9s/python-developer-berkeley-ca
# 200 https://www.postjobfree.com/resume/adhth5/software-developer-python-dallas-tx
# 200 https://www.postjobfree.com/resume/adhs9a/python-developer-hampton-va
# 200 https://www.postjobfree.com/resume/adhs5x/python-developer-denver-co
# 200 https://www.postjobfree.com/resume/adhrjm/python-developer-new-brunswick-nj
# 200 https://www.postjobfree.com/resume/adhnr4/software-developer-python-pearland-tx
# 200 https://www.postjobfree.com/resume/adhioe/python-developer-edison-nj
# 200 https://www.postjobfree.com/resume/adhhd8/software-developer-python-clifton-nj
# 200 https://www.postjobfree.com/resume/adhcud/software-developer-python-gainesville-fl
# 200 https://www.postjobfree.com/resume/adhbct/python-developer-atlanta-ga-30301
# 200 https://www.postjobfree.com/resume/adg3yi/software-developer-python-jersey-city-nj
# 200 https://www.postjobfree.com/resume/adg3s6/python-developer-frisco-tx
# 200 https://www.postjobfree.com/resume/adg1bn/python-developer-st-louis-mo
# 200 https://www.postjobfree.com/resume/adgp7c/python-developer-newport-ky
# 200 https://www.postjobfree.com/resume/adgpbh/python-developer-los-angeles-ca
# 200 https://www.postjobfree.com/resume/adgo77/python-software-developer-chandler-az
# 200 https://www.postjobfree.com/resume/adgocm/python-developer-los-angeles-ca
# 200 https://www.postjobfree.com/resume/adgnjv/pl-sql-developer-with-python-skokie-il
# 200 https://www.postjobfree.com/resume/adgmm8/web-developer-python-port-gibson-ms
# 200 https://www.postjobfree.com/resume/adglz6/python-developer-boston-ma
# 200 https://www.postjobfree.com/resume/adgakp/python-developer-brentwood-tn
# 200 https://www.postjobfree.com/resume/adf6ii/python-aws-practitioner-vba-brooklyn-ny
# 200 https://www.postjobfree.com/resume/adf5rd/python-aws-hadoop-jira-etl-mvc-tampa-fl
# 200 https://www.postjobfree.com/resume/adf23n/python-web-developer-russian-spring-tx
# 200 https://www.postjobfree.com/resume/adf2bj/azure-aws-accenture-python-seattle-wa
# 200 https://www.postjobfree.com/resume/adfyk1/aws-python-wcf-js-pleasant-grove-ut
# 200 https://www.postjobfree.com/resume/adftzu/ambassador-data-analyst-python-dallas-or
# 200 https://www.postjobfree.com/resume/adfk7v/c-python-android-game-java-binghamton-ny
# 200 https://www.postjobfree.com/resume/adff5u/python-jira-amazon-vmware-baton-rouge-la
# 200 https://www.postjobfree.com/resume/ade38b/jira-software-developer-msc-north-ma
# 200 https://www.postjobfree.com/resume/ade17g/aws-js-python-tableau-chef-texas-city-tx
# 200 https://www.postjobfree.com/resume/ade03g/developer-python-mvc-jira-princeton-nj
# 200 https://www.postjobfree.com/resume/adeyrk/python-chinese-reservoir-vba-houston-tx
# 200 https://www.postjobfree.com/resume/adem6x/aws-etl-python-amazon-chef-englewood-co
# 200 https://www.postjobfree.com/resume/adem15/python-app-html5-scrum-massapequa-ny
# 200 https://www.postjobfree.com/resume/adej01/aws-azure-python-mvc-cloud-charlotte-nc
# 200 https://www.postjobfree.com/resume/adej0z/python-hibernate-aws-golf-ios-grafton-ma
# 200 https://www.postjobfree.com/resume/adeagn/js-aws-hadoop-python-arlington-heights
# 200 https://www.postjobfree.com/resume/add8p6/python-js-developer-app-ui-sunnyvale-ca
# 200 https://www.postjobfree.com/resume/add5n0/mvc-tfs-python-hadoop-glass-fairfield-ia
# 200 https://www.postjobfree.com/resume/add1hv/sql-hcm-salesforce-python-aws-sanford-fl
# 200 https://www.postjobfree.com/resume/addxo3/azure-aws-amazon-mvc-python-arlington-tx
# 200 https://www.postjobfree.com/resume/addubd/selenium-python-jira-html5-js-denver-co
# 200 https://www.postjobfree.com/resume/addos7/aws-python-etl-azure-richmond-va
# 200 https://www.postjobfree.com/resume/addivd/python-salesforce-js-abap-binghamton-ny
# 200 https://www.postjobfree.com/resume/adda44/selenium-python-amazon-scrum-austin-tx

# %%
url = "https://www.postjobfree.com/resumes?q=title%3A%28software+engineer+intern%29&l=United+States&radius=25"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
title_tags = soup.find_all('h3', attrs={'class': 'itemTitle'})
links = ["https://www.postjobfree.com" + title_tag.a['href'] for title_tag in title_tags]
results = []
for link in links:
    res = requests.get(link)
    print(res.status_code, link)
    content = BeautifulSoup(res.content, 'html.parser')
    results.append({
        'job_title': content.find('div', attrs={'class': 'leftColumn'}).find('h1').get_text(),
        'resume': content.find('div', attrs={'class': 'normalText'}).get_text()[:-23]
    })
    time.sleep(3)
with open('resumes.csv', 'w') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=results[0].keys())
    writer.writeheader()
    for row in results:
        writer.writerow(row)
# Out:
# 200 https://www.postjobfree.com/resume/adk83f/software-engineer-intern-san-diego-ca
# 200 https://www.postjobfree.com/resume/adkd12/software-engineer-intern-providence-ri
# 200 https://www.postjobfree.com/resume/adjl2c/software-engineer-intern-arlington-tx
# 200 https://www.postjobfree.com/resume/adhw5v/software-engineer-analyst-santa-clara-ca
# 200 https://www.postjobfree.com/resume/adhs5o/database-system-developer-pittsburgh-pa
# 200 https://www.postjobfree.com/resume/adhrlr/software-engineer-intern-clemson-sc
# 200 https://www.postjobfree.com/resume/adg4af/software-engineer-intern-chicago-il
# 200 https://www.postjobfree.com/resume/adeyw7/sas-data-analyst-game-san-francisco-ca
# 200 https://www.postjobfree.com/resume/addqhf/js-aws-python-selenium-mvc-app-durham-nc
# 200 https://www.postjobfree.com/resume/adcjpp/mvc-hibernate-attendant-writer-austin-tx

# %%
url = "https://www.livecareer.com/resume-search/search?jt=software%20engineer"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
title_tags = soup.find_all('h3', attrs={'class': 'itemTitle'})
links = ["https://www.postjobfree.com" + title_tag.a['href'] for title_tag in title_tags]
results = []
for link in links:
    res = requests.get(link)
    print(res.status_code, link)
    content = BeautifulSoup(res.content, 'html.parser')
    results.append({
        'job_title': content.find('div', attrs={'class': 'leftColumn'}).find('h1').get_text(),
        'resume': content.find('div', attrs={'class': 'normalText'}).get_text()[:-23]
    })
    time.sleep(3)
with open('resumes.csv', 'w') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=results[0].keys())
    writer.writeheader()
    for row in results:
